# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data=pd.read_csv("UK_Accident.csv")

# %%
data.head()
# Out:
#    Unnamed: 0 Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  \
# 0           0  200501BS00001               525680.0                178240.0
# 1           1  200501BS00002               524170.0                181650.0
# 2           2  200501BS00003               524520.0                182240.0
# 3           3  200501BS00004               526900.0                177530.0
# 4           4  200501BS00005               528060.0                179040.0
#
#    Longitude   Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  -0.191170  51.489096             1                  2                   1
# 1  -0.211708  51.520075             1                  3                   1
# 2  -0.206458  51.525301             1                  3                   2
# 3  -0.173862  51.482442             1                  3                   1
# 4  -0.156618  51.495752             1                  3                   1
#
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1504150 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Unnamed: 0                                   1504150 non-null  int64
#  1   Accident_Index                               1504150 non-null  object
#  2   Location_Easting_OSGR                        1504049 non-null  float64
#  3   Location_Northing_OSGR                       1504150 non-null  float64
#  4   Longitude                                    1504049 non-null  float64
#  5   Latitude                                     1504150 non-null  float64
#  6   Police_Force                                 1504150 non-null  int64
#  7   Accident_Severity                            1504150 non-null  int64
#  8   Number_of_Vehicles                           1504150 non-null  int64
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0  Location_Easting_OSGR  Location_Northing_OSGR  \
# count  1.504150e+06           1.504049e+06            1.504150e+06
# mean   2.530433e+05           4.396214e+05            3.001382e+05
# std    1.489162e+05           9.511616e+04            1.610218e+05
# min    0.000000e+00           6.495000e+04            0.000000e+00
# 25%    1.253452e+05           3.750600e+05            1.782600e+05
# 50%    2.506910e+05           4.399600e+05            2.688000e+05
# 75%    3.760370e+05           5.230600e+05            3.981500e+05
# max    5.700100e+05           6.553700e+05            1.208800e+06
#
#           Longitude      Latitude  Police_Force  Accident_Severity  \
# count  1.504049e+06  1.504150e+06  1.504150e+06       1.504150e+06
# mean  -1.436625e+00  5.258587e+01  3.020536e+01       2.838190e+00
# std    1.398078e+00  1.512524e+00  2.551603e+01       4.018423e-01
# min   -7.516225e+00  0.000000e+00  1.000000e+00       1.000000e+00
# ...

# %%
data.dropna(subset=['Location_Easting_OSGR'], inplace=True)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1504049 entries, 0 to 1504149
# Data columns (total 33 columns):
#  #   Column                                       Non-Null Count    Dtype
# ---  ------                                       --------------    -----
#  0   Unnamed: 0                                   1504049 non-null  int64
#  1   Accident_Index                               1504049 non-null  object
#  2   Location_Easting_OSGR                        1504049 non-null  float64
#  3   Location_Northing_OSGR                       1504049 non-null  float64
#  4   Longitude                                    1504049 non-null  float64
#  5   Latitude                                     1504049 non-null  float64
#  6   Police_Force                                 1504049 non-null  int64
#  7   Accident_Severity                            1504049 non-null  int64
#  8   Number_of_Vehicles                           1504049 non-null  int64
# ...

# %%
sns.histplot(data['Accident_Severity'])
plt.xlabel('Accident Severity')
plt.ylabel('Count')
plt.title('Distribution of Accident Severity')
plt.show()

# %%
sns.countplot(data['Road_Type'])
plt.xlabel('Road_Type')
plt.ylabel('count')
plt.title('Distribution of road type')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
data_cas={'Casuality count' : data['Number_of_Casualties'],
          
    'Day_of_Week': data['Day_of_Week']
}
accidents_per_week = pd.DataFrame(data_cas)
accidents_per_week.groupby(by='Day_of_Week').sum().sort_values(by='Day_of_Week',ascending=True)
# Out:
#              Casuality count
# Day_of_Week
# 1                     239519
# 2                     284027
# 3                     294464
# 4                     297730
# 5                     299019
# 6                     331905
# 7                     285248

# %%
plt.figure(figsize=(10, 8))
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
#plt.figure(figsize=(12, 6))
data['Date'] = pd.to_datetime(data['Date'])
data['Year']= data['Date'].dt.year
accidents_by_year = data['Year'].value_counts().sort_index()
sns.lineplot(x=accidents_by_year.index, y=accidents_by_year.values)
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.title('Accidents Over Time')
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(x='Light_Conditions', y="Number_of_Casualties",data=data)
plt.xlabel('Light_Conditions')
plt.ylabel('Number_of_Casualties')
plt.title("Light_Conditions V/S Number_of_Casualties")
plt.xticks(rotation=46)
plt.show()

# %%
sns.lineplot(x=('Day_of_Week'), y="Number_of_Casualties",data=data)
plt.xlabel('Day_of_Week')
plt.ylabel('Number_of_Casualties')
plt.title("Day_of_Week V/S Number_of_Casualties")
plt.xticks(rotation=46)
plt.show()

# %%
sns.boxplot(x='Road_Surface_Conditions', y="Number_of_Casualties",data=data)
plt.xlabel('Road_Surface_Conditions')
plt.ylabel('Number_of_Casualties')
plt.title("Road_Surface_Conditions V/S Number_of_Casualties")
plt.xticks(rotation=46)
plt.show()

# %%
sns.barplot(x='Pedestrian_Crossing-Human_Control', y="Number_of_Casualties",data=data)
plt.xlabel('Pedestrian_Crossing-Human_Control')
plt.ylabel('Number_of_Casualties')
plt.title("Pedestrian_Crossing-Human_Control V/S Number_of_Casualties")
plt.xticks(rotation=46)
plt.show()

# %%
sns.barplot(x='Pedestrian_Crossing-Physical_Facilities', y="Number_of_Casualties",data=data)
plt.xlabel('Pedestrian_Crossing-Physical_Facilities')
plt.ylabel('Number_of_Casualties')
plt.title("Pedestrian_Crossing-Physical_Facilities V/S Number_of_Casualties")
plt.xticks(rotation=75)
plt.show()

# %%
sns.scatterplot(x="Number_of_Casualties",y="Number_of_Vehicles",data=data,palette="Speed_limit")
plt.xlabel('Number_of_Casualties')
plt.ylabel('Number_of_Vehicles')
plt.title("Correlation between Number_of_Vehicles and Number_of_Casualties")
plt.show()

# %%
sns.lineplot(x="Speed_limit",y="Number_of_Casualties",data=data)
plt.xlabel('Speed_limit')
plt.ylabel('Number_of_Casualties')
plt.title("Speed_limit VS Number_of_Casualties")
plt.show()

# %%
sns.barplot(x='Urban_or_Rural_Area', y="Number_of_Casualties",data=data,hue="Did_Police_Officer_Attend_Scene_of_Accident")
plt.xlabel('Urban_or_Rural_Area')
plt.ylabel('Number_of_Casualties')
plt.title("Urban_or_Rural_Area V/S Number_of_Casualties")
plt.xticks(rotation=75)
plt.show()

# %%
sns.barplot(x='Carriageway_Hazards', y="Number_of_Casualties",data=data)
plt.xlabel('Carriageway_Hazards')
plt.ylabel('Number_of_Casualties')
plt.title("Carriageway_Hazards V/S Number_of_Casualties")
plt.xticks(rotation=85)
plt.show()

# %%
sns.lineplot(x="Accident_Severity",y="Number_of_Casualties",data=data)
plt.xlabel('Accident_Severity')
plt.ylabel('Number_of_Casualties')
plt.title("Accident_Severity VS Number_of_Casualties")
plt.show()

# %%
sns.barplot(x='Special_Conditions_at_Site', y="Number_of_Casualties",data=data)
plt.xlabel('Special_Conditions_at_Site')
plt.ylabel('Number_of_Casualties')
plt.title("Carriageway_Hazards V/S Number_of_Casualties")
plt.xticks(rotation=85)
plt.show()

# %%
sns.barplot(x='Road_Surface_Conditions', y="Number_of_Casualties",data=data)
plt.xlabel('Road_Surface_Conditions')
plt.ylabel('Number_of_Casualties')
plt.title("Road_Surface_Conditions V/S Number_of_Casualties")
plt.xticks(rotation=85)
plt.show()

# %%
sns.lineplot(x='Road_Type', y="Number_of_Casualties",data=data)
plt.xlabel('Road_Type')
plt.ylabel('Number_of_Casualties')
plt.title("Road_Surface_Conditions V/S Number_of_Casualties")
plt.xticks(rotation=85)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=('Year'), y="Number_of_Casualties",data=data)
plt.xlabel('Year')
plt.ylabel('Number_of_Casualties')
plt.title("Year V/S Number_of_Casualties")
plt.xticks(rotation=46)
plt.show()
