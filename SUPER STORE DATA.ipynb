# %%
#import the required  library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# read the data file 
data=pd.read_excel("superstore_sales.xlsx")

# %%
data
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
data.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %%
#Information of the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %%
#checking for data summary of continious data
data.describe()
# Out:
#               sales      quantity      discount        profit  shipping_cost  \
# count  51290.000000  51290.000000  51290.000000  51290.000000   51290.000000
# mean     246.490581      3.476545      0.142908     28.641740      26.375818
# std      487.565361      2.278766      0.212280    174.424113      57.296810
# min        0.444000      1.000000      0.000000  -6599.978000       0.002000
# 25%       30.758625      2.000000      0.000000      0.000000       2.610000
# 50%       85.053000      3.000000      0.000000      9.240000       7.790000
# 75%      251.053200      5.000000      0.200000     36.810000      24.450000
# max    22638.480000     14.000000      0.850000   8399.976000     933.570000
#
#                year
# count  51290.000000
# mean    2012.777208
# std        1.098931
# min     2011.000000
# 25%     2012.000000
# 50%     2013.000000
# 75%     2014.000000
# max     2014.000000

# %%
#taking random sample from the data  
data.sample(5)
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 13687   CA-2012-160472 2012-07-20 2012-07-25    Second Class
# 50746  ES-2014-2572542 2014-12-24 2014-12-24        Same Day
# 21780   CA-2013-127670 2013-03-21 2013-03-25  Standard Class
# 50117   CA-2014-122770 2014-12-14 2014-12-19  Standard Class
# 12346  ES-2012-2141914 2012-06-07 2012-06-11    Second Class
#
#           customer_name      segment          state        country market  \
# 13687     Ralph Kennedy     Consumer        Indiana  United States     US
# 50746  Natalie Fritzler     Consumer  Ile-de-France         France     EU
# 21780    Robert Dilbeck  Home Office       Missouri  United States     US
# 50117        Emily Phan     Consumer     California  United States     US
# 12346     Mark Hamilton     Consumer  Ile-de-France         France     EU
#
#         region  ...         category sub_category  \
# 13687  Central  ...  Office Supplies    Envelopes
# ...

# %%
#check for duplicate data
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# There is no duplicate data in the dataset.

# %%
#checking for null values in the data set

data.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %% [markdown]
# There is no null values in the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %%
#checking the shiping mode for order 
data["ship_mode"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='ship_mode'>

# %%
plt.figure(figsize=(7, 5))

# countplot: Show the counts of observations in each categorical bin using bars
sns.countplot(x='ship_mode', data=data, order=)

# Display the figure
plt.show()

# %% [markdown]
# From the above pie chart and barchart, we observe that 60% of people choose the standard class shipping mode. Only 5% of people use same-day delivery, and 15% opt for first-class delivery. The remaining individuals prefer the second-class delivery option.

# %%
#order categorization
data["segment"].value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='segment'>

# %% [markdown]
# The entire set of orders is divided into three categories: 1) Consumer Goods, 2) Corporate, and 3) Home Office. Among these categories, 53% of the orders are from the Consumer Goods category, 27% are from the Corporate category, and the remaining orders are from the Home Office category.

# %%
plt.figure(figsize=(5,25))

# countplot: Show the counts of observations in each categorical bin using bars
sns.barplot(x='sales', y='country',data=data)

# Display the figure
plt.show()

# %%
plt.figure(figsize=(6,22))
sns.countplot(y="country",data=data)
plt.show()

# %% [markdown]
# From the above graphs, we can observe that the United States has a significantly large number of orders, approximately 10,000. However, the average amount spent per order is relatively low, around 300. The price variability in the US orders ranges from 240 to 350.
#
# In contrast, Montenegro has the highest average sale value, with variations ranging from 18 to 2500. This suggests that people in the US are less inclined to make expensive purchases through superstores.

# %%
#order by market
sns.countplot(x="market",data=data,)
# Out:
# <AxesSubplot:xlabel='market', ylabel='count'>

# %% [markdown]
# The APAC market has the highest maximum number of orders, followed by LATAM, the US, and then the EU. Conversely, Canada has the fewest number of orders among these regions.

# %%
#further categorization of market order
sns.countplot(x="market",data=data,hue='category')
# Out:
# <AxesSubplot:xlabel='market', ylabel='count'>

# %% [markdown]
# Upon further categorization of market orders, it is evident that office supplies have the highest number of orders across all worldwide markets.

# %%
# barplot: Sales Vs market
sns.barplot(x='market', y='sales',data=data,ci=None)

# Display the figure
plt.show()

# %% [markdown]
# APAC superstore have highest no of sales followed by EU, US, LATAM, Canada while EMEA has minimum no of sale.

# %%
# countplot: Show the counts of observations in each categorical bin using bars
sns.barplot(x='market', y='sales',data=data,ci=None,hue='category')

# Display the figure
plt.show()

# %%
# countplot: Show the counts of observations in each categorical bin using bars
sns.barplot(x='market', y='profit',data=data,ci=None,hue='category')

# Display the figure
plt.show()

# %% [markdown]
# But, in terms of sales and profit, Technology sector is a leader among all the categories

# %%
# countplot: Show the counts of observations in each categorical bin using bars
sns.barplot(x='market', y='discount',data=data,ci=None,hue='')

# Display the figure
plt.show()

# %%
# countplot: Show the counts of observations in each categorical bin using bars
sns.lineplot(x='year', y='sales',data=data,ci=None,hue='category')

# Display the figure
plt.show()

# %%
sns.lineplot(x='year', y='profit',data=data,ci=None,hue='category')

# Display the figure
plt.show()

# %%
# countplot: Show the counts of observations in each categorical bin using bars
sns.barplot(x='sub_category', y='sales',data=data,ci=None,)
sns.lineplot(x='sub_category', y='profit',data=data,ci=None,)
plt.xticks(rotation=45)
# Display the figure
plt.show()

# %% [markdown]
# Tables have highest no of sales but still it is loss making product. On the other, Appliances are the most profitable products.

# %%
sns.lineplot(x='sub_category', y='discount',data=data,ci=None,)
#sns.barplot(x='sub_category', y='profit',data=data,ci=None,)
plt.xticks(rotation=45)
plt.show()

# %%
sns.barplot(x='order_priority', y='sales',data=data,ci=None,)
sns.lineplot(x='order_priority', y='profit',data=data,)
plt.xticks(rotation=45)
# Display the figure
plt.show()
